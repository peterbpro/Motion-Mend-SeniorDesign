# %%
import opensim as osim
from bleak import BleakClient
from datetime import datetime
from math import pi
import os, math, time, sys
import asyncio
from pathlib import Path

# %%
################################# VARIABLE SETUP ################################################
FILEPATH = Path('c:\\Users\\kenzo\\Documents\\SENIOR DESIGN\\MotionMend\\Hardware\\Experimental\\Simulation')
BLE_DURATION_SECONDS = 20
CAPTURE_NEW_DATA = True # False if you want to visualize the latest motion captured
RECALIBRATE = False

### BLUETOOTH VARIABLES ###
ESP32_MAC_ADDRESS = "65DAA853-64CB-A387-AEE5-CDF0A60B786C"
ESP32_MAC_ADDRESS = "14:2B:2F:AF:81:96"
ESP32_MAC_ADDRESS = "14:2B:2F:AE:BC:86"
SERVICE_UUID = "6E400001-B5A3-F393-E0A9-E50E24DCCA9E"
CHARACTERISTIC_UUID_TX = "6E400003-B5A3-F393-E0A9-E50E24DCCA9E"
FILENAME_SUFFIX = datetime.today().strftime('%Y_%m_%d_%H_%M')
FILE_HEADER = '''DataType=Quaternion
endheader'''
STO_FILENAME = os.path.join(FILEPATH, 'data', f'data_{FILENAME_SUFFIX}.sto')
RAW_DATA_FILENAME = os.path.join(FILEPATH, 'data', f'data_raw_{FILENAME_SUFFIX}.txt')
### SIMULATION FILE PATH VARIABLES ###
modelFileName = os.path.join(FILEPATH, 'models','Rajagopal_2015.osim')          # The path to an input model
outputCalibratedFileName = os.path.join(FILEPATH, 'models', 'calibrated_model.osim')
resultsDirectory = os.path.join(FILEPATH, 'IK_results')
MOT_FILENAME = os.path.join(resultsDirectory, f'ik_data_{FILENAME_SUFFIX}.mot')

### CALIBRATION VARIABLES ###
sensor_to_opensim_rotations = osim.Vec3(-pi/2, 0, 0)# The rotation of IMU data to the OpenSim world frame
baseIMUName = 'pelvis_imu'                     # The base IMU is the IMU on the base body of the model that dictates the heading (forward) direction of the model.
baseIMUHeading = '-z'                           # The Coordinate Axis of the base IMU that points in the heading direction. 
visulizeCalibration = False                     # Boolean to Visualize the Output model

### INVERSE KINEMATICS VARIABLES ###
sensor_to_opensim_rotation = osim.Vec3(-pi/2, 0, 0) # The rotation of IMU data to the OpenSim world frame
visualizeTracking = True  # Boolean to Visualize the tracking simulation
startTime = 0           # Start time (in seconds) of the tracking simulation. 
endTime = 1000              # End time (in seconds) of the tracking simulation.

# %%
imuIK = osim.IMUInverseKinematicsTool()
 
# Set tool properties
imuIK.set_model_file(outputCalibratedFileName)
imuIK.set_sensor_to_opensim_rotations(sensor_to_opensim_rotation)
imuIK.set_results_directory(resultsDirectory)

# Set time range in seconds
imuIK.set_time_range(0, startTime) 
imuIK.set_time_range(1, endTime)   

model = osim.Model(outputCalibratedFileName)

relevant_coords = set([
    # 'hip_flexion_r',
    # 'hip_adduction_r',
    # 'hip_rotation_r',
    'knee_angle_r',
    'knee_angle_r_beta',
    # 'hip_flexion_l',
    # 'hip_adduction_l',
    # 'hip_rotation_l',
    # 'knee_angle_l',
    # 'knee_angle_l_beta'
])

timestamp = time.time() 

tibia0, femur0 = 6, 11

# %%
class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout
        
# Function to convert Roll, Pitch, Yaw to Quaternion
def rpy_to_quaternion(roll, pitch, yaw):
    # Convert angles to radians
    roll = math.radians(roll)
    pitch = math.radians(pitch)
    yaw = math.radians(yaw)

    # Quaternion conversion
    q_w = math.cos(roll/2) * math.cos(pitch/2) * math.cos(yaw/2) + math.sin(roll/2) * math.sin(pitch/2) * math.sin(yaw/2)
    q_x = math.sin(roll/2) * math.cos(pitch/2) * math.cos(yaw/2) - math.cos(roll/2) * math.sin(pitch/2) * math.sin(yaw/2)
    q_y = math.cos(roll/2) * math.sin(pitch/2) * math.cos(yaw/2) + math.sin(roll/2) * math.cos(pitch/2) * math.sin(yaw/2)
    q_z = math.cos(roll/2) * math.cos(pitch/2) * math.sin(yaw/2) - math.sin(roll/2) * math.sin(pitch/2) * math.cos(yaw/2)

    return q_w, q_x, q_y, q_z

# Callback function to handle incoming data from ESP32
def notification_handler(sender, data):
    try:
        timestamp = time.time()
        # Decode incoming data (need to add encoding on ESP32 side)
        decoded_data = data.decode('utf-8').strip()

        # Split the incoming data by comma
        values = decoded_data.split(',')
                
        # Open the .sto file in append mode
        # buf = [f"{FILE_HEADER}\ntime\tpelvis_imu\tfemur_r_imu\ttibia_r_imu\n0"]
        with open(STO_FILENAME, 'w') as file:
            femur, tibia = 0, 0
            
            # Iterate through each IMU set of data
            for i in range(0, len(values), 3):        
                roll = float(values[i])
                pitch = float(values[i + 1])
                yaw = float(values[i + 2])
                
                if i == 3:
                    femur = pitch
                if i == 6:
                    tibia = pitch

                # Convert RPY to quaternion
                if i > 0:
                    print(f'{"femur" if i == 3 else "tibia"}: {roll}, {pitch}, {yaw}')
                # q_w, q_x, q_y, q_z = rpy_to_quaternion(roll, pitch, yaw)


                # Append quaternion data to the file
                # buf.append(f"\t{q_w:.6f},{q_x:.6f},{q_y:.6f},{q_z:.6f}")
                
            print(f'computed angle: {(femur0 - femur) - (tibia0 - tibia)}')
            # file.write(''.join(buf))        
        
        # Run IK
        # with HiddenPrints():

        # imuIK = osim.IMUInverseKinematicsTool()
        # # Set tool properties
        # imuIK.set_model_file(outputCalibratedFileName)
        # imuIK.set_sensor_to_opensim_rotations(sensor_to_opensim_rotation)
        # imuIK.set_results_directory(resultsDirectory)

        # # Set time range in seconds
        # imuIK.set_time_range(0, startTime) 
        # imuIK.set_time_range(1, endTime)   

        # model = osim.Model(outputCalibratedFileName)
        
        # imuIK.set_orientations_file(STO_FILENAME);
        # # imuIK.run();

        # q = osim.TimeSeriesTable(MOT_FILENAME)
        
        # for i,t in enumerate(q.getIndependentColumn()):
        #     value=osim.RowVector(q.getRowAtIndex(i))
        #     for j, coordinate in enumerate(model.updCoordinateSet()):
        #         if coordinate.getName() in relevant_coords:
        #             print(t, coordinate.getName(), value[j])
        print(f'{(time.time() - timestamp)*1000:.1f}ms')

    except ValueError as e:
        print(f"Error parsing data: {data}. Error: {e}")

async def run():
    async with BleakClient(ESP32_MAC_ADDRESS) as client:
        connected = await client.is_connected()
        print(f"Connected: {connected}")

        await client.start_notify(CHARACTERISTIC_UUID_TX, notification_handler)

        await asyncio.sleep(BLE_DURATION_SECONDS)  # Run for 1 min 

        await client.stop_notify(CHARACTERISTIC_UUID_TX)

# %%
BLE_DURATION_SECONDS = 20
await run()
# Out:
# C:\Users\kenzo\AppData\Local\Temp\ipykernel_33488\3848255457.py:95: FutureWarning: is_connected has been changed to a property. Calling it as an async method will be removed in a future version
#   connected = await client.is_connected()
# Connected: True
# femur: 90.93, 10.79, 0.0
# tibia: 103.3, 6.78, 0.0
# computed angle: -0.5699999999999994
# 0.0ms
# femur: 90.81, 10.97, 0.0
# tibia: 103.33, 6.95, 0.0
# computed angle: -0.9200000000000008
# 0.7ms
# femur: 90.81, 11.13, 0.0
# tibia: 103.36, 6.85, 0.0
# computed angle: -0.9800000000000004
# 0.0ms
# femur: 90.84, 10.92, 0.0
# tibia: 103.4, 6.74, 0.0
# computed angle: -0.6600000000000001
# 0.0ms
# femur: 90.81, 10.86, 0.0
# tibia: 103.51, 6.71, 0.0
# computed angle: -0.5699999999999994
# 0.0ms
# femur: 90.84, 10.82, 0.0
# tibia: 103.41, 6.56, 0.0
# computed angle: -0.3799999999999999
# 0.0ms
# femur: 90.88, 11.0, 0.0
# tibia: 103.5, 6.61, 0.0
# computed angle: -0.6100000000000003
# 0.0ms
# femur: 90.79, 11.15, 0.0
# tibia: 103.46, 6.79, 0.0
# computed angle: -0.9400000000000004
# 14.9ms
# femur: 90.77, 11.16, 0.0
# tibia: 103.58, 6.6, 0.0
# computed angle: -0.7599999999999998
# 0.0ms
# femur: 90.89, 10.85, 0.0
# tibia: 103.68, 6.36, 0.0
# computed angle: -0.20999999999999996
# 4.5ms
# femur: 91.11, 10.36, 0.0
# tibia: 103.96, 5.92, 0.0
# computed angle: 0.7200000000000006
# 13.7ms
# femur: 91.34, 10.08, 0.0
# tibia: 104.15, 5.68, 0.0
# computed angle: 1.2400000000000002
# 0.0ms
# femur: 91.48, 10.16, 0.0
# tibia: 104.28, 5.8, 0.0
# computed angle: 1.04
# 0.0ms
# femur: 91.41, 10.32, 0.0
# tibia: 104.37, 5.79, 0.0
# computed angle: 0.8899999999999997
# 4.3ms
# femur: 91.27, 10.48, 0.0
# tibia: 104.41, 5.82, 0.0
# computed angle: 0.6999999999999993
# 0.0ms
# femur: 91.26, 10.46, 0.0
# tibia: 104.39, 5.76, 0.0
# computed angle: 0.7799999999999994
# 0.0ms
# femur: 91.24, 10.32, 0.0
# tibia: 104.35, 5.7, 0.0
# computed angle: 0.9799999999999995
# 0.0ms
# femur: 91.1, 10.16, 0.0
# tibia: 104.35, 5.64, 0.0
# computed angle: 1.2000000000000002
# 0.0ms
# femur: 90.88, 10.22, 0.0
# tibia: 104.33, 5.55, 0.0
# computed angle: 1.2299999999999995
# 0.0ms
# femur: 90.75, 10.18, 0.0
# tibia: 104.31, 5.58, 0.0
# computed angle: 1.2400000000000002
# 0.0ms
# femur: 90.81, 9.72, 0.0
# tibia: 104.21, 5.28, 0.0
# computed angle: 1.9999999999999991
# 0.0ms
# femur: 90.95, 9.4, 0.0
# tibia: 104.24, 5.08, 0.0
# computed angle: 2.5199999999999996
# 0.0ms
# femur: 90.9, 9.19, 0.0
# tibia: 104.15, 4.97, 0.0
# computed angle: 2.8400000000000007
# 1.0ms
# femur: 90.95, 9.07, 0.0
# tibia: 104.11, 4.91, 0.0
# computed angle: 3.0199999999999996
# 0.0ms
# femur: 90.96, 8.91, 0.0
# tibia: 104.06, 4.69, 0.0
# computed angle: 3.3999999999999995
# 0.0ms
# femur: 90.99, 8.76, 0.0
# tibia: 104.05, 4.56, 0.0
# computed angle: 3.6800000000000006
# 0.0ms
# femur: 90.91, 8.71, 0.0
# tibia: 103.87, 4.64, 0.0
# computed angle: 3.6499999999999995
# 0.0ms
# femur: 90.67, 9.06, 0.0
# tibia: 103.86, 4.76, 0.0
# computed angle: 3.1799999999999997
# 0.0ms
# femur: 90.64, 8.34, 0.0
# tibia: 103.66, 4.32, 0.0
# computed angle: 4.34
# 0.0ms
# femur: 90.8, 7.98, 0.0
# tibia: 103.81, 4.16, 0.0
# computed angle: 4.859999999999999
# 0.0ms
# femur: 90.64, 7.33, 0.0
# tibia: 103.56, 3.48, 0.0
# computed angle: 6.1899999999999995
# 0.0ms
# femur: 90.79, 7.06, 0.0
# tibia: 103.71, 3.47, 0.0
# computed angle: 6.470000000000001
# 0.0ms
# femur: 90.85, 6.86, 0.0
# tibia: 103.72, 3.08, 0.0
# computed angle: 7.06
# 0.0ms
# femur: 90.76, 6.75, 0.0
# tibia: 103.73, 2.8, 0.0
# computed angle: 7.45
# 0.0ms
# femur: 90.83, 6.64, 0.0
# tibia: 103.8, 2.64, 0.0
# computed angle: 7.720000000000001
# 0.0ms
# femur: 90.96, 6.44, 0.0
# tibia: 103.78, 2.14, 0.0
# computed angle: 8.42
# 0.0ms
# femur: 90.97, 6.36, 0.0
# tibia: 103.83, 2.08, 0.0
# computed angle: 8.559999999999999
# 0.0ms
# femur: 91.2, 6.36, 0.0
# tibia: 103.98, 1.67, 0.0
# computed angle: 8.969999999999999
# 11.6ms
# femur: 91.33, 6.09, 0.0
# tibia: 103.97, 1.52, 0.0
# computed angle: 9.39
# 0.0ms
# femur: 91.51, 5.8, 0.0
# tibia: 103.99, 1.15, 0.0
# computed angle: 10.05
# 0.0ms
# femur: 91.6, 5.6, 0.0
# tibia: 103.99, 0.94, 0.0
# computed angle: 10.46
# 0.0ms
# femur: 91.78, 5.3, 0.0
# tibia: 103.96, 0.88, 0.0
# computed angle: 10.82
# 0.0ms
# femur: 91.92, 4.84, 0.0
# tibia: 103.78, 0.75, 0.0
# computed angle: 11.41
# 0.0ms
# femur: 91.9, 4.73, 0.0
# tibia: 103.66, 1.06, 0.0
# computed angle: 11.209999999999999
# 0.0ms
# femur: 91.69, 4.13, 0.0
# tibia: 103.29, 0.95, 0.0
# computed angle: 11.92
# 0.0ms
# femur: 91.47, 2.69, 0.0
# tibia: 102.78, 0.62, 0.0
# computed angle: 13.690000000000001
# 0.0ms
# femur: 91.23, 0.66, 0.0
# tibia: 102.64, 0.84, 0.0
# computed angle: 15.5
# 0.0ms
# femur: 91.31, 0.06, 0.0
# tibia: 102.55, 2.05, 0.0
# computed angle: 14.89
# 0.0ms
# femur: 91.19, -0.54, 0.0
# tibia: 102.07, 3.35, 0.0
# computed angle: 14.19
# 0.1ms
# femur: 90.88, -1.21, 0.0
# tibia: 99.95, 4.19, 0.0
# computed angle: 14.02
# 2.2ms
# femur: 90.6, -1.72, 0.0
# tibia: 98.22, 5.66, 0.0
# computed angle: 13.06
# 0.0ms
# femur: 90.24, -1.66, 0.0
# tibia: 97.36, 7.58, 0.0
# computed angle: 11.08
# 0.0ms
# femur: 89.4, -1.86, 0.0
# tibia: 96.85, 9.43, 0.0
# computed angle: 9.43
# 0.0ms
# femur: 88.87, -2.95, 0.0
# tibia: 95.44, 9.31, 0.0
# computed angle: 10.639999999999999
# 0.0ms
# femur: 88.48, -3.98, 0.0
# tibia: 95.01, 8.88, 0.0
# computed angle: 12.1
# 0.5ms
# femur: 88.6, -6.17, 0.0
# tibia: 94.76, 7.47, 0.0
# computed angle: 15.700000000000003
# 0.0ms
# femur: 89.11, -7.49, 0.0
# tibia: 94.64, 5.83, 0.0
# computed angle: 18.660000000000004
# 0.0ms
# femur: 89.28, -9.4, 0.0
# tibia: 94.35, 3.88, 0.0
# computed angle: 22.52
# 0.0ms
# femur: 89.14, -10.86, 0.0
# tibia: 93.96, 1.58, 0.0
# computed angle: 26.28
# 0.0ms
# femur: 88.84, -11.83, 0.0
# tibia: 93.16, -0.07, 0.0
# computed angle: 28.9
# 0.0ms
# femur: 88.44, -12.08, 0.0
# tibia: 92.85, -1.07, 0.0
# computed angle: 30.15
# 0.4ms
# femur: 88.27, -11.99, 0.0
# tibia: 92.99, -1.52, 0.0
# computed angle: 30.51
# 0.0ms
# femur: 88.13, -11.69, 0.0
# tibia: 92.97, -1.85, 0.0
# computed angle: 30.54
# 0.0ms
# femur: 88.23, -11.76, 0.0
# tibia: 93.02, -2.66, 0.0
# computed angle: 31.419999999999998
# 0.0ms
# femur: 88.52, -11.68, 0.0
# tibia: 93.33, -3.19, 0.0
# computed angle: 31.869999999999997
# 1.1ms
# femur: 88.85, -11.27, 0.0
# tibia: 93.62, -3.56, 0.0
# computed angle: 31.83
# 0.0ms
# femur: 89.28, -11.03, 0.0
# tibia: 94.2, -4.08, 0.0
# computed angle: 32.11
# 0.5ms
# femur: 89.6, -10.77, 0.0
# tibia: 94.59, -4.54, 0.0
# computed angle: 32.31
# 0.0ms
# femur: 90.04, -10.41, 0.0
# tibia: 95.19, -4.89, 0.0
# computed angle: 32.3
# 0.0ms
# femur: 90.38, -9.92, 0.0
# tibia: 95.81, -5.06, 0.0
# computed angle: 31.98
# 0.0ms
# femur: 90.84, -9.43, 0.0
# tibia: 96.36, -5.24, 0.0
# computed angle: 31.67
# 0.0ms
# femur: 91.23, -8.75, 0.0
# tibia: 96.92, -5.32, 0.0
# computed angle: 31.07
# 0.0ms
# femur: 91.68, -7.91, 0.0
# tibia: 97.7, -5.33, 0.0
# computed angle: 30.240000000000002
# 0.0ms
# femur: 91.96, -7.25, 0.0
# tibia: 98.25, -5.32, 0.0
# computed angle: 29.57
# 0.0ms
# femur: 92.34, -6.44, 0.0
# tibia: 98.9, -5.21, 0.0
# computed angle: 28.650000000000002
# 0.0ms
# femur: 92.63, -5.77, 0.0
# tibia: 99.51, -5.08, 0.0
# computed angle: 27.85
# 0.0ms
# femur: 92.9, -4.93, 0.0
# tibia: 100.09, -4.74, 0.0
# computed angle: 26.67
# 0.0ms
# femur: 93.1, -4.08, 0.0
# tibia: 100.61, -4.53, 0.0
# computed angle: 25.61
# 0.0ms
# femur: 93.34, -3.48, 0.0
# tibia: 101.18, -4.39, 0.0
# computed angle: 24.87
# 0.0ms
# femur: 93.56, -2.84, 0.0
# tibia: 101.47, -4.1, 0.0
# computed angle: 23.939999999999998
# 0.0ms
# femur: 93.8, -2.28, 0.0
# tibia: 102.0, -3.91, 0.0
# computed angle: 23.189999999999998
# 0.0ms
# femur: 93.98, -1.81, 0.0
# tibia: 102.5, -3.75, 0.0
# computed angle: 22.560000000000002
# 0.0ms
# femur: 94.21, -1.45, 0.0
# tibia: 102.86, -3.77, 0.0
# computed angle: 22.22
# 0.0ms
# femur: 94.4, -1.05, 0.0
# tibia: 103.32, -3.67, 0.0
# computed angle: 21.72
# 3.0ms
# femur: 94.59, -0.78, 0.0
# tibia: 103.65, -3.61, 0.0
# computed angle: 21.39
# 0.0ms
# femur: 94.79, -0.46, 0.0
# tibia: 103.94, -3.57, 0.0
# computed angle: 21.03
# 0.0ms
# femur: 94.81, -0.12, 0.0
# tibia: 104.24, -3.44, 0.0
# computed angle: 20.56
# 0.0ms
# femur: 94.87, 0.19, 0.0
# tibia: 104.5, -3.43, 0.0
# computed angle: 20.240000000000002
# 0.0ms
# femur: 95.03, 0.49, 0.0
# tibia: 104.83, -3.3, 0.0
# computed angle: 19.810000000000002
# 0.0ms
# femur: 95.11, 0.73, 0.0
# tibia: 105.03, -3.18, 0.0
# computed angle: 19.45
# 8.0ms
# femur: 95.13, 0.94, 0.0
# tibia: 105.17, -3.13, 0.0
# computed angle: 19.189999999999998
# 0.0ms
# femur: 95.2, 1.2, 0.0
# tibia: 105.31, -3.03, 0.0
# computed angle: 18.83
# 0.0ms
# femur: 95.13, 1.35, 0.0
# tibia: 105.49, -2.92, 0.0
# computed angle: 18.57
# 0.0ms
# femur: 95.12, 1.51, 0.0
# tibia: 105.62, -2.89, 0.0
# computed angle: 18.380000000000003
# 0.0ms
# femur: 95.18, 1.68, 0.0
# tibia: 105.78, -2.75, 0.0
# computed angle: 18.07
# 0.0ms
# femur: 95.17, 1.81, 0.0
# tibia: 105.87, -2.65, 0.0
# computed angle: 17.84
# 0.0ms
# femur: 95.17, 1.96, 0.0
# tibia: 106.06, -2.59, 0.0
# computed angle: 17.63
# 0.6ms
# femur: 95.17, 2.08, 0.0
# tibia: 106.08, -2.55, 0.0
# computed angle: 17.47
# 0.0ms
# femur: 95.17, 2.22, 0.0
# tibia: 106.19, -2.55, 0.0
# computed angle: 17.33
# 2.2ms
# femur: 95.1, 2.34, 0.0
# tibia: 106.3, -2.47, 0.0
# computed angle: 17.130000000000003
# 0.0ms
# femur: 95.06, 2.45, 0.0
# tibia: 106.3, -2.38, 0.0
# computed angle: 16.93
# 0.0ms
# femur: 95.09, 2.52, 0.0
# tibia: 106.38, -2.3, 0.0
# computed angle: 16.78
# 0.0ms
# femur: 95.13, 2.58, 0.0
# tibia: 106.43, -2.34, 0.0
# computed angle: 16.759999999999998
# 0.0ms
# femur: 95.14, 2.54, 0.0
# tibia: 106.48, -2.25, 0.0
# computed angle: 16.71
# 0.0ms
# femur: 95.16, 2.65, 0.0
# tibia: 106.55, -2.32, 0.0
# computed angle: 16.67
# 0.0ms
# femur: 95.15, 2.71, 0.0
# tibia: 106.59, -2.24, 0.0
# computed angle: 16.53
# 0.0ms
# femur: 95.1, 2.76, 0.0
# tibia: 106.66, -2.27, 0.0
# computed angle: 16.509999999999998
# 0.0ms
# femur: 95.1, 2.73, 0.0
# tibia: 106.7, -2.18, 0.0
# computed angle: 16.45
# 0.0ms
# femur: 95.06, 2.78, 0.0
# tibia: 106.72, -2.06, 0.0
# computed angle: 16.28
# 0.0ms
# femur: 95.0, 2.88, 0.0
# tibia: 106.69, -1.99, 0.0
# computed angle: 16.11
# 0.0ms
# femur: 94.99, 2.93, 0.0
# tibia: 106.73, -1.97, 0.0
# computed angle: 16.04
# 0.0ms
# femur: 94.98, 2.98, 0.0
# tibia: 106.72, -1.91, 0.0
# computed angle: 15.93
# 0.0ms
# femur: 94.96, 2.99, 0.0
# tibia: 106.75, -1.85, 0.0
# computed angle: 15.86
# 0.0ms
# femur: 94.92, 3.02, 0.0
# tibia: 106.78, -1.78, 0.0
# computed angle: 15.760000000000002
# 0.0ms
# femur: 94.95, 3.0, 0.0
# tibia: 106.76, -1.77, 0.0
# computed angle: 15.77
# 6.0ms
# femur: 94.93, 3.1, 0.0
# tibia: 106.69, -1.76, 0.0
# computed angle: 15.66
# 0.0ms
# femur: 94.92, 3.12, 0.0
# tibia: 106.74, -1.68, 0.0
# computed angle: 15.559999999999999
# 0.0ms
# femur: 94.97, 3.12, 0.0
# tibia: 106.68, -1.62, 0.0
# computed angle: 15.5
# 0.0ms
# femur: 94.93, 3.13, 0.0
# tibia: 106.71, -1.55, 0.0
# computed angle: 15.42
# 0.0ms
# femur: 94.93, 3.15, 0.0
# tibia: 106.74, -1.48, 0.0
# computed angle: 15.33
# 13.6ms
# femur: 94.99, 3.15, 0.0
# tibia: 106.71, -1.45, 0.0
# computed angle: 15.3
# 0.0ms
# femur: 94.94, 3.13, 0.0
# tibia: 106.75, -1.41, 0.0
# computed angle: 15.280000000000001
# 1.0ms
# femur: 94.92, 3.14, 0.0
# tibia: 106.77, -1.41, 0.0
# computed angle: 15.27
# 0.0ms
# femur: 94.91, 3.11, 0.0
# tibia: 106.76, -1.4, 0.0
# computed angle: 15.290000000000001
# 0.0ms
# femur: 94.94, 3.1, 0.0
# tibia: 106.77, -1.38, 0.0
# computed angle: 15.280000000000001
# 0.6ms
# femur: 94.98, 3.05, 0.0
# tibia: 106.73, -1.29, 0.0
# computed angle: 15.24
# 0.0ms
# femur: 94.97, 3.05, 0.0
# tibia: 106.73, -1.22, 0.0
# computed angle: 15.17
# 0.0ms
# femur: 95.01, 3.04, 0.0
# tibia: 106.61, -1.18, 0.0
# computed angle: 15.14
# 0.0ms
# femur: 95.05, 3.03, 0.0
# tibia: 106.59, -1.19, 0.0
# computed angle: 15.16
# 0.0ms
# femur: 95.09, 2.95, 0.0
# tibia: 106.54, -1.17, 0.0
# computed angle: 15.22
# 0.0ms
# femur: 95.1, 2.95, 0.0
# tibia: 106.58, -1.17, 0.0
# computed angle: 15.22
# 0.0ms
# femur: 95.09, 2.91, 0.0
# tibia: 106.57, -1.14, 0.0
# computed angle: 15.23
# 0.0ms
# femur: 95.11, 2.9, 0.0
# tibia: 106.49, -1.14, 0.0
# computed angle: 15.239999999999998
# 6.1ms
# femur: 95.18, 2.87, 0.0
# tibia: 106.49, -1.16, 0.0
# computed angle: 15.29
# 0.0ms
# femur: 95.18, 2.87, 0.0
# tibia: 106.44, -1.13, 0.0
# computed angle: 15.259999999999998
# 0.0ms
# femur: 95.14, 2.81, 0.0
# tibia: 106.44, -1.12, 0.0
# computed angle: 15.309999999999999
# 0.0ms
# femur: 95.1, 2.74, 0.0
# tibia: 106.43, -1.12, 0.0
# computed angle: 15.379999999999999
# 0.0ms
# femur: 95.05, 2.77, 0.0
# tibia: 106.39, -1.13, 0.0
# computed angle: 15.36
# 0.0ms
# femur: 94.99, 2.76, 0.0
# tibia: 106.39, -1.11, 0.0
# computed angle: 15.350000000000001
# 0.0ms
# femur: 94.98, 2.76, 0.0
# tibia: 106.38, -1.08, 0.0
# computed angle: 15.32
# 0.0ms
# femur: 94.99, 2.66, 0.0
# tibia: 106.33, -1.09, 0.0
# computed angle: 15.43
# 0.0ms
# femur: 95.01, 2.63, 0.0
# tibia: 106.29, -1.07, 0.0
# computed angle: 15.440000000000001
# 0.0ms
# femur: 94.98, 2.61, 0.0
# tibia: 106.24, -1.01, 0.0
# computed angle: 15.4
# 0.0ms
# femur: 94.97, 2.58, 0.0
# tibia: 106.19, -0.92, 0.0
# computed angle: 15.34
# 0.0ms
# femur: 94.91, 2.56, 0.0
# tibia: 106.18, -0.91, 0.0
# computed angle: 15.35
# 0.0ms
# femur: 94.91, 2.51, 0.0
# tibia: 106.19, -0.93, 0.0
# computed angle: 15.42
# 0.0ms
# femur: 94.8, 2.52, 0.0
# tibia: 105.81, -1.22, 0.0
# computed angle: 15.7
# 0.4ms
# femur: 94.74, 2.58, 0.0
# tibia: 105.92, -1.36, 0.0
# computed angle: 15.780000000000001
# 0.0ms
# femur: 94.56, 2.46, 0.0
# tibia: 105.87, -1.32, 0.0
# computed angle: 15.86
# 0.0ms
# femur: 95.0, 2.77, 0.0
# tibia: 106.06, -1.07, 0.0
# computed angle: 15.3
# 0.0ms
# femur: 95.29, 2.82, 0.0
# tibia: 106.25, -0.92, 0.0
# computed angle: 15.1
# 1.1ms
# femur: 95.41, 2.79, 0.0
# tibia: 106.37, -0.92, 0.0
# computed angle: 15.13
# 0.0ms
# femur: 95.3, 2.13, 0.0
# tibia: 105.98, -1.35, 0.0
# computed angle: 16.22
# 4.0ms
# femur: 95.29, 1.23, 0.0
# tibia: 105.78, -1.99, 0.0
# computed angle: 17.759999999999998
# 0.0ms
# femur: 95.43, 1.25, 0.0
# tibia: 105.9, -1.86, 0.0
# computed angle: 17.61
# 0.0ms
# femur: 95.28, 1.0, 0.0
# tibia: 105.52, -2.08, 0.0
# computed angle: 18.08
# 0.0ms
# femur: 94.79, 1.42, 0.0
# tibia: 105.32, -1.61, 0.0
# computed angle: 17.19
# 0.0ms
# femur: 94.42, 1.58, 0.0
# tibia: 105.14, -1.28, 0.0
# computed angle: 16.7
# 0.0ms
# femur: 94.13, 1.56, 0.0
# tibia: 104.88, -1.01, 0.0
# computed angle: 16.45
# 0.0ms
# femur: 93.74, 1.8, 0.0
# tibia: 104.48, -0.75, 0.0
# computed angle: 15.95
# 0.0ms
# femur: 93.3, 2.14, 0.0
# tibia: 104.15, -0.32, 0.0
# computed angle: 15.18
# 0.0ms
# femur: 92.86, 2.62, 0.0
# tibia: 103.83, 0.11, 0.0
# computed angle: 14.27
# 0.0ms
# femur: 92.42, 2.73, 0.0
# tibia: 103.55, 0.57, 0.0
# computed angle: 13.7
# 0.5ms
# femur: 92.18, 2.93, 0.0
# tibia: 103.25, 0.97, 0.0
# computed angle: 13.100000000000001
# 0.0ms
# femur: 91.85, 3.06, 0.0
# tibia: 102.92, 1.28, 0.0
# computed angle: 12.66
# 0.0ms
# femur: 91.5, 3.21, 0.0
# tibia: 102.61, 1.62, 0.0
# computed angle: 12.17
# 0.0ms
# femur: 91.19, 3.48, 0.0
# tibia: 102.19, 1.85, 0.0
# computed angle: 11.67
# 0.0ms
# femur: 91.07, 3.56, 0.0
# tibia: 101.97, 2.18, 0.0
# computed angle: 11.26
# 0.0ms
# femur: 90.79, 3.58, 0.0
# tibia: 101.58, 2.3, 0.0
# computed angle: 11.120000000000001
# 0.0ms
# femur: 90.47, 3.69, 0.0
# tibia: 101.41, 2.61, 0.0
# computed angle: 10.700000000000001
# 0.0ms
# femur: 90.21, 3.99, 0.0
# tibia: 101.22, 2.87, 0.0
# computed angle: 10.14
# 0.0ms
# femur: 89.9, 4.28, 0.0
# tibia: 101.01, 3.25, 0.0
# computed angle: 9.469999999999999
# 0.0ms
# femur: 89.57, 4.42, 0.0
# tibia: 100.76, 3.7, 0.0
# computed angle: 8.879999999999999
# 0.0ms
# femur: 89.34, 4.55, 0.0
# tibia: 100.63, 4.08, 0.0
# computed angle: 8.370000000000001
# 0.0ms
# femur: 89.25, 4.42, 0.0
# tibia: 100.4, 4.06, 0.0
# computed angle: 8.52
# 0.0ms
# femur: 89.12, 4.15, 0.0
# tibia: 100.19, 3.95, 0.0
# computed angle: 8.899999999999999
# 0.0ms
# femur: 89.06, 3.91, 0.0
# tibia: 100.01, 4.06, 0.0
# computed angle: 9.030000000000001
# 4.8ms
# femur: 88.88, 3.79, 0.0
# tibia: 99.77, 4.2, 0.0
# computed angle: 9.01
# 0.0ms
# femur: 88.7, 3.73, 0.0
# tibia: 99.43, 4.35, 0.0
# computed angle: 8.92
# 0.0ms
# femur: 88.54, 3.73, 0.0
# tibia: 99.2, 4.53, 0.0
# computed angle: 8.739999999999998
# 0.0ms
# femur: 88.37, 3.62, 0.0
# tibia: 98.97, 4.73, 0.0
# computed angle: 8.649999999999999
# 0.0ms
# femur: 88.32, 3.47, 0.0
# tibia: 98.88, 4.62, 0.0
# computed angle: 8.91
# 0.0ms
# femur: 88.24, 3.33, 0.0
# tibia: 98.59, 4.72, 0.0
# computed angle: 8.95
# 0.0ms
# femur: 88.15, 3.19, 0.0
# tibia: 98.41, 4.79, 0.0
# computed angle: 9.02
# 0.0ms
# femur: 88.06, 3.08, 0.0
# tibia: 98.27, 4.94, 0.0
# computed angle: 8.98
# 0.0ms
# femur: 87.98, 2.88, 0.0
# tibia: 98.16, 4.94, 0.0
# computed angle: 9.18
# 0.0ms
# femur: 87.91, 2.72, 0.0
# tibia: 98.03, 5.01, 0.0
# computed angle: 9.27
# 0.0ms
# femur: 87.9, 2.59, 0.0
# tibia: 98.0, 5.04, 0.0
# computed angle: 9.370000000000001
# 0.0ms
# femur: 87.88, 2.45, 0.0
# tibia: 97.97, 5.0, 0.0
# computed angle: 9.55
# 0.0ms
# femur: 87.92, 2.25, 0.0
# tibia: 97.94, 4.98, 0.0
# computed angle: 9.77
# 0.0ms
# femur: 88.01, 2.15, 0.0
# tibia: 97.87, 4.99, 0.0
# computed angle: 9.86
# 2.8ms
# femur: 88.06, 1.98, 0.0
# tibia: 97.82, 4.96, 0.0
# computed angle: 10.059999999999999
# 0.0ms
# femur: 88.12, 1.84, 0.0
# tibia: 97.81, 4.92, 0.0
# computed angle: 10.24
# 0.8ms
# femur: 88.18, 1.7, 0.0
# tibia: 97.78, 4.94, 0.0
# computed angle: 10.36
# 0.0ms
# femur: 88.33, 1.66, 0.0
# tibia: 97.77, 4.94, 0.0
# computed angle: 10.399999999999999
# 0.0ms
# femur: 88.47, 1.59, 0.0
# tibia: 97.8, 4.91, 0.0
# computed angle: 10.5
# 0.0ms
# femur: 88.59, 1.54, 0.0
# tibia: 97.83, 4.9, 0.0
# computed angle: 10.56
# 0.0ms
# femur: 88.69, 1.56, 0.0
# tibia: 97.9, 4.93, 0.0
# computed angle: 10.51
# 0.0ms
# femur: 88.88, 1.52, 0.0
# tibia: 97.97, 5.02, 0.0
# computed angle: 10.46
# 0.0ms
# femur: 89.04, 1.54, 0.0
# tibia: 97.99, 5.06, 0.0
# computed angle: 10.400000000000002
# 0.0ms
# femur: 89.17, 1.56, 0.0
# tibia: 98.01, 5.08, 0.0
# computed angle: 10.36
# 0.0ms
# femur: 89.27, 1.61, 0.0
# tibia: 98.01, 5.1, 0.0
# computed angle: 10.290000000000001
# 0.0ms
# femur: 89.38, 1.64, 0.0
# tibia: 98.12, 5.08, 0.0
# computed angle: 10.28
# 0.0ms
# femur: 89.51, 1.68, 0.0
# tibia: 98.16, 5.09, 0.0
# computed angle: 10.23
# 0.0ms
# femur: 89.65, 1.73, 0.0
# tibia: 98.18, 5.08, 0.0
# computed angle: 10.19
# 0.0ms
# femur: 89.85, 1.75, 0.0
# tibia: 98.32, 5.03, 0.0
# computed angle: 10.219999999999999
# 0.0ms
# femur: 89.9, 1.72, 0.0
# tibia: 98.46, 4.99, 0.0
# computed angle: 10.29
# 0.0ms
# femur: 89.99, 1.66, 0.0
# tibia: 98.48, 5.01, 0.0
# computed angle: 10.33
# 0.0ms
# femur: 90.12, 1.71, 0.0
# tibia: 98.57, 4.99, 0.0
# computed angle: 10.299999999999999
# 0.0ms
# femur: 90.29, 1.76, 0.0
# tibia: 98.64, 4.98, 0.0
# computed angle: 10.26
# 0.0ms
# femur: 90.36, 1.84, 0.0
# tibia: 98.73, 5.07, 0.0
# computed angle: 10.09
# 0.0ms
# femur: 90.42, 1.9, 0.0
# tibia: 98.78, 5.03, 0.0
# computed angle: 10.07
# 0.0ms
# femur: 90.58, 1.91, 0.0
# tibia: 98.89, 5.17, 0.0
# computed angle: 9.92
# 0.0ms
# femur: 90.48, 1.88, 0.0
# tibia: 98.83, 5.09, 0.0
# computed angle: 10.030000000000001
# 0.0ms
# femur: 91.13, 1.3, 0.0
# tibia: 99.04, 4.13, 0.0
# computed angle: 11.57
# 8.8ms
# femur: 91.91, 0.42, 0.0
# tibia: 99.33, 3.54, 0.0
# computed angle: 13.04
# 0.0ms
# femur: 92.27, -0.17, 0.0
# tibia: 99.53, 3.29, 0.0
# computed angle: 13.879999999999999
# 0.0ms
# femur: 92.37, -1.18, 0.0
# tibia: 99.31, 3.07, 0.0
# computed angle: 15.11
# 0.8ms
# femur: 92.24, -1.53, 0.0
# tibia: 99.04, 3.91, 0.0
# computed angle: 14.62
# 0.0ms
# femur: 92.2, -2.83, 0.0
# tibia: 99.09, 4.79, 0.0
# computed angle: 15.04
# 0.0ms
# femur: 92.53, -4.53, 0.0
# tibia: 98.88, 4.75, 0.0
# computed angle: 16.78
# 0.0ms
# femur: 92.55, -6.19, 0.0
# tibia: 99.65, 7.32, 0.0
# computed angle: 15.870000000000001
# 0.0ms
# femur: 93.27, -8.62, 0.0
# tibia: 98.78, 9.11, 0.0
# computed angle: 16.509999999999998
# 0.0ms
# femur: 94.01, -11.13, 0.0
# tibia: 97.75, 11.44, 0.0
# computed angle: 16.690000000000005
# 0.0ms
# femur: 94.63, -13.87, 0.0
# tibia: 97.01, 13.09, 0.0
# computed angle: 17.779999999999998
# 0.0ms
# femur: 95.62, -16.66, 0.0
# tibia: 95.74, 15.26, 0.0
# computed angle: 18.4
# 0.0ms
# femur: 96.2, -19.78, 0.0
# tibia: 94.73, 17.48, 0.0
# computed angle: 19.3
# 0.0ms
# femur: 97.02, -22.9, 0.0
# tibia: 93.88, 19.59, 0.0
# computed angle: 20.31
# 3.0ms
# femur: 97.94, -26.17, 0.0
# tibia: 93.65, 21.91, 0.0
# computed angle: 21.26
# 7.5ms
# femur: 99.65, -29.28, 0.0
# tibia: 79.79, 26.64, 0.0
# computed angle: 19.64
# 0.5ms
# femur: 99.83, -32.91, 0.0
# tibia: 68.23, 30.78, 0.0
# computed angle: 19.129999999999995
# 2.0ms
# femur: 100.81, -36.37, 0.0
# tibia: 69.42, 32.47, 0.0
# computed angle: 20.9
# 0.0ms
# femur: 101.72, -39.19, 0.0
# tibia: 71.05, 34.27, 0.0
# computed angle: 21.919999999999995
# 0.0ms
# femur: 103.31, -42.14, 0.0
# tibia: 72.78, 34.89, 0.0
# computed angle: 24.25
# 0.0ms
# femur: 105.25, -44.94, 0.0
# tibia: 74.29, 35.27, 0.0
# computed angle: 26.669999999999995
# 0.0ms
# femur: 106.99, -47.77, 0.0
# tibia: 75.69, 35.48, 0.0
# computed angle: 29.290000000000006
# 0.0ms
# femur: 108.61, -50.07, 0.0
# tibia: 76.76, 35.61, 0.0
# computed angle: 31.46
# 2.0ms
# femur: 109.84, -52.1, 0.0
# tibia: 77.89, 35.82, 0.0
# computed angle: 33.28
# 0.5ms
# femur: 110.68, -53.9, 0.0
# tibia: 78.59, 36.02, 0.0
# computed angle: 34.88
# 0.0ms
# femur: 111.48, -55.35, 0.0
# tibia: 79.39, 36.57, 0.0
# computed angle: 35.779999999999994
# 0.0ms
# femur: 112.03, -56.54, 0.0
# tibia: 80.05, 36.99, 0.0
# computed angle: 36.54999999999999
# 0.0ms
# femur: 112.34, -57.71, 0.0
# tibia: 80.8, 37.43, 0.0
# computed angle: 37.28000000000001
# 0.0ms
# femur: 112.55, -58.58, 0.0
# tibia: 81.41, 38.02, 0.0
# computed angle: 37.559999999999995
# 0.0ms
# femur: 112.89, -58.93, 0.0
# tibia: 81.88, 38.18, 0.0
# computed angle: 37.75000000000001
# 0.0ms
# femur: 113.33, -59.14, 0.0
# tibia: 82.13, 38.64, 0.0
# computed angle: 37.5
# 0.8ms
# femur: 113.19, -58.78, 0.0
# tibia: 82.5, 39.04, 0.0
# computed angle: 36.74
# 0.0ms
# femur: 112.99, -58.21, 0.0
# tibia: 82.83, 39.01, 0.0
# computed angle: 36.20000000000001
# 0.0ms
# femur: 112.72, -57.45, 0.0
# tibia: 82.93, 38.52, 0.0
# computed angle: 35.93
# 0.0ms
# femur: 111.73, -56.48, 0.0
# tibia: 83.07, 38.19, 0.0
# computed angle: 35.28999999999999
# 0.0ms
# femur: 111.51, -55.1, 0.0
# tibia: 83.2, 37.22, 0.0
# computed angle: 34.879999999999995
# 0.0ms
# femur: 110.54, -53.65, 0.0
# tibia: 83.45, 36.17, 0.0
# computed angle: 34.480000000000004
# 0.0ms
# femur: 109.66, -51.75, 0.0
# tibia: 83.72, 35.21, 0.0
# computed angle: 33.54
# 0.6ms
# femur: 108.15, -49.39, 0.0
# tibia: 84.03, 34.51, 0.0
# computed angle: 31.880000000000003
# 0.6ms
# femur: 106.96, -46.53, 0.0
# tibia: 85.07, 33.25, 0.0
# computed angle: 30.28
# 0.0ms
# femur: 105.7, -43.89, 0.0
# tibia: 86.51, 33.0, 0.0
# computed angle: 27.89
# 0.0ms
# femur: 104.09, -41.57, 0.0
# tibia: 87.84, 30.09, 0.0
# computed angle: 28.48
# 0.0ms
# femur: 103.64, -39.45, 0.0
# tibia: 88.95, 27.1, 0.0
# computed angle: 29.35
# 0.0ms
# femur: 102.77, -37.52, 0.0
# tibia: 89.67, 25.23, 0.0
# computed angle: 29.290000000000003
# 0.0ms
# femur: 102.03, -34.17, 0.0
# tibia: 90.5, 24.07, 0.0
# computed angle: 27.1
# 0.0ms
# femur: 101.0, -30.82, 0.0
# tibia: 91.16, 22.79, 0.0
# computed angle: 25.03
# 0.0ms
# femur: 100.0, -27.93, 0.0
# tibia: 91.91, 21.14, 0.0
# computed angle: 23.79
# 0.0ms
# femur: 99.32, -25.03, 0.0
# tibia: 92.86, 19.44, 0.0
# computed angle: 22.59
# 0.0ms
# femur: 98.46, -22.52, 0.0
# tibia: 93.74, 17.56, 0.0
# computed angle: 21.959999999999997
# 0.0ms
# femur: 98.14, -19.96, 0.0
# tibia: 94.68, 16.1, 0.0
# computed angle: 20.86
# 0.6ms
# femur: 97.62, -17.42, 0.0
# tibia: 95.53, 14.54, 0.0
# computed angle: 19.880000000000003
# 0.0ms
# femur: 97.2, -14.73, 0.0
# tibia: 96.6, 13.54, 0.0
# computed angle: 18.19
# 0.0ms
# femur: 96.88, -12.12, 0.0
# tibia: 97.5, 12.55, 0.0
# computed angle: 16.569999999999997
# 0.0ms
# femur: 96.63, -9.7, 0.0
# tibia: 98.44, 11.48, 0.0
# computed angle: 15.219999999999999
# 0.0ms
# femur: 96.47, -7.41, 0.0
# tibia: 99.43, 10.66, 0.0
# computed angle: 13.75
# 0.0ms
# femur: 96.29, -5.34, 0.0
# tibia: 100.39, 9.91, 0.0
# computed angle: 12.43
# 0.0ms
# femur: 96.1, -3.52, 0.0
# tibia: 101.14, 9.16, 0.0
# computed angle: 11.36
# 0.8ms
# femur: 95.91, -1.9, 0.0
# tibia: 101.84, 8.17, 0.0
# computed angle: 10.73
# 0.0ms
# femur: 95.84, -0.5, 0.0
# tibia: 102.61, 7.3, 0.0
# computed angle: 10.2
# 0.0ms
# femur: 95.71, 0.93, 0.0
# tibia: 103.35, 6.74, 0.0
# computed angle: 9.33
# 0.0ms
# femur: 95.33, 2.69, 0.0
# tibia: 103.65, 6.31, 0.0
# computed angle: 8.0
# 9.0ms
# femur: 94.94, 3.99, 0.0
# tibia: 103.82, 6.01, 0.0
# computed angle: 7.0
# 0.0ms
# femur: 94.37, 5.4, 0.0
# tibia: 104.08, 5.74, 0.0
# computed angle: 5.859999999999999
# 1.0ms
# femur: 93.96, 6.36, 0.0
# tibia: 104.31, 5.0, 0.0
# computed angle: 5.64
# 0.0ms
# femur: 93.81, 7.29, 0.0
# tibia: 104.84, 4.48, 0.0
# computed angle: 5.2299999999999995
# 0.0ms
# femur: 93.56, 8.22, 0.0
# tibia: 105.1, 4.13, 0.0
# computed angle: 4.6499999999999995
# 1.4ms
# femur: 93.09, 8.82, 0.0
# tibia: 105.18, 3.61, 0.0
# computed angle: 4.57
# 0.0ms
# femur: 92.8, 9.16, 0.0
# tibia: 105.19, 3.38, 0.0
# computed angle: 4.46
# 0.0ms
# femur: 92.57, 9.39, 0.0
# tibia: 105.02, 3.14, 0.0
# computed angle: 4.469999999999999
# 0.0ms
# femur: 92.34, 9.09, 0.0
# tibia: 104.97, 2.74, 0.0
# computed angle: 5.17
# 0.0ms
# femur: 92.3, 8.36, 0.0
# tibia: 104.95, 2.3, 0.0
# computed angle: 6.340000000000001
# 0.0ms
# femur: 92.02, 7.74, 0.0
# tibia: 104.43, 2.66, 0.0
# computed angle: 6.6
# 0.0ms
# femur: 91.78, 6.47, 0.0
# tibia: 104.24, 2.96, 0.0
# computed angle: 7.57
# 0.0ms
# femur: 91.74, 5.32, 0.0
# tibia: 104.12, 3.79, 0.0
# computed angle: 7.89
# 0.0ms
# femur: 91.96, 4.09, 0.0
# tibia: 104.29, 5.46, 0.0
# computed angle: 7.45
# 0.0ms
# femur: 92.17, 1.95, 0.0
# tibia: 103.35, 8.56, 0.0
# computed angle: 6.49
# 0.0ms
# femur: 92.7, -0.04, 0.0
# tibia: 101.24, 8.58, 0.0
# computed angle: 8.459999999999999
# 0.0ms
# femur: 93.22, -2.8, 0.0
# tibia: 99.9, 10.75, 0.0
# computed angle: 9.05
# 0.0ms
# femur: 93.54, -5.59, 0.0
# tibia: 99.12, 13.11, 0.0
# computed angle: 9.48
# 0.0ms
# femur: 94.15, -8.54, 0.0
# tibia: 98.09, 15.5, 0.0
# computed angle: 10.04
# 0.0ms
# femur: 94.76, -11.68, 0.0
# tibia: 97.43, 17.97, 0.0
# computed angle: 10.71
# 1.5ms
# femur: 95.75, -14.91, 0.0
# tibia: 97.28, 20.79, 0.0
# computed angle: 11.120000000000001
# 0.0ms
# femur: 97.12, -18.09, 0.0
# tibia: 97.05, 23.06, 0.0
# computed angle: 12.030000000000001
# 0.0ms
# femur: 98.38, -21.49, 0.0
# tibia: 97.0, 25.07, 0.0
# computed angle: 13.419999999999995
# 0.0ms
# femur: 99.8, -25.19, 0.0
# tibia: 97.09, 26.64, 0.0
# computed angle: 15.549999999999997
# 0.0ms
# femur: 101.16, -28.68, 0.0
# tibia: 97.23, 27.91, 0.0
# computed angle: 17.77
# 1.0ms
# femur: 102.43, -32.4, 0.0
# tibia: 96.96, 29.0, 0.0
# computed angle: 20.4
# 1.0ms
# femur: 104.57, -36.2, 0.0
# tibia: 96.65, 30.04, 0.0
# computed angle: 23.160000000000004
# 0.0ms
# femur: 106.4, -39.5, 0.0
# tibia: 96.35, 31.1, 0.0
# computed angle: 25.4
# 0.0ms
# femur: 107.66, -42.53, 0.0
# tibia: 96.41, 31.81, 0.0
# computed angle: 27.720000000000002
# 0.0ms
# femur: 108.62, -45.35, 0.0
# tibia: 96.5, 32.25, 0.0
# computed angle: 30.1
# 0.0ms
# femur: 109.61, -47.91, 0.0
# tibia: 96.65, 32.49, 0.0
# computed angle: 32.419999999999995
# 0.0ms
# femur: 110.53, -50.26, 0.0
# tibia: 96.6, 32.63, 0.0
# computed angle: 34.629999999999995
# 1.6ms
# femur: 111.43, -52.29, 0.0
# tibia: 96.54, 32.63, 0.0
# computed angle: 36.66
# 0.0ms
# femur: 112.37, -54.13, 0.0
# tibia: 96.41, 32.54, 0.0
# computed angle: 38.589999999999996
# 0.0ms
# femur: 113.37, -55.89, 0.0
# tibia: 96.3, 32.4, 0.0
# computed angle: 40.49
# 0.6ms
# femur: 114.33, -57.4, 0.0
# tibia: 95.85, 32.16, 0.0
# computed angle: 42.24000000000001
# 0.0ms
# femur: 114.94, -58.68, 0.0
# tibia: 95.35, 32.42, 0.0
# computed angle: 43.260000000000005
# 0.0ms
# femur: 114.82, -59.53, 0.0
# tibia: 95.19, 32.9, 0.0
# computed angle: 43.63
# 0.0ms
# femur: 114.69, -60.12, 0.0
# tibia: 94.72, 33.3, 0.0
# computed angle: 43.82000000000001
# 0.5ms
# femur: 114.4, -60.69, 0.0
# tibia: 94.42, 33.68, 0.0
# computed angle: 44.01
# 0.0ms
# femur: 114.05, -60.6, 0.0
# tibia: 94.06, 34.03, 0.0
# computed angle: 43.56999999999999
# 0.0ms
# femur: 113.94, -60.27, 0.0
# tibia: 93.19, 34.27, 0.0
# computed angle: 43.00000000000001
# 1.5ms
# femur: 113.11, -59.6, 0.0
# tibia: 92.6, 34.8, 0.0
# computed angle: 41.8
# 0.0ms
# femur: 112.53, -58.68, 0.0
# tibia: 92.1, 34.57, 0.0
# computed angle: 41.11000000000001
# 0.0ms
# femur: 111.88, -57.49, 0.0
# tibia: 91.41, 34.67, 0.0
# computed angle: 39.82000000000001
# 1.3ms
# femur: 110.94, -55.99, 0.0
# tibia: 91.0, 34.0, 0.0
# computed angle: 38.99000000000001
# 0.0ms
# femur: 109.84, -54.22, 0.0
# tibia: 90.67, 34.31, 0.0
# computed angle: 36.91
# 0.0ms
# femur: 108.92, -51.84, 0.0
# tibia: 90.43, 34.06, 0.0
# computed angle: 34.78
# 14.1ms
# femur: 107.66, -49.29, 0.0
# tibia: 90.62, 33.72, 0.0
# computed angle: 32.57
# 2.3ms
# femur: 105.93, -45.96, 0.0
# tibia: 90.95, 32.24, 0.0
# computed angle: 30.72
# 0.0ms
# femur: 104.04, -43.57, 0.0
# tibia: 91.53, 30.17, 0.0
# computed angle: 30.4
# 0.0ms
# femur: 102.44, -40.84, 0.0
# tibia: 91.94, 28.34, 0.0
# computed angle: 29.500000000000004
# 2.1ms
# femur: 101.97, -38.3, 0.0
# tibia: 92.3, 25.89, 0.0
# computed angle: 29.409999999999997
# 0.0ms
# femur: 101.72, -36.16, 0.0
# tibia: 93.62, 23.69, 0.0
# computed angle: 29.469999999999995
# 0.0ms
# femur: 100.72, -32.92, 0.0
# tibia: 93.47, 22.67, 0.0
# computed angle: 27.25
# 6.8ms
# femur: 99.45, -29.57, 0.0
# tibia: 93.43, 21.28, 0.0
# computed angle: 25.29
# 0.0ms
# femur: 98.57, -26.74, 0.0
# tibia: 93.85, 19.63, 0.0
# computed angle: 24.109999999999996
# 0.0ms
# femur: 97.7, -23.92, 0.0
# tibia: 93.98, 18.33, 0.0
# computed angle: 22.590000000000003
# 0.0ms
# femur: 96.76, -21.17, 0.0
# tibia: 94.33, 17.06, 0.0
# computed angle: 21.110000000000003
# 0.0ms
# femur: 96.15, -18.6, 0.0
# tibia: 94.65, 15.84, 0.0
# computed angle: 19.76
# 0.0ms
# femur: 95.42, -16.08, 0.0
# tibia: 94.87, 14.66, 0.0
# computed angle: 18.419999999999998
# 0.0ms
# femur: 94.66, -13.64, 0.0
# tibia: 95.08, 13.7, 0.0
# computed angle: 16.94
# 1.3ms
# femur: 94.01, -11.17, 0.0
# tibia: 95.37, 12.42, 0.0
# computed angle: 15.750000000000002
# 0.0ms
# femur: 93.47, -9.12, 0.0
# tibia: 95.61, 11.59, 0.0
# computed angle: 14.529999999999998
# 0.0ms
# femur: 93.1, -7.13, 0.0
# tibia: 95.91, 11.08, 0.0
# computed angle: 13.049999999999999
# 0.0ms
# femur: 92.52, -5.21, 0.0
# tibia: 95.97, 10.43, 0.0
# computed angle: 11.780000000000001
# 0.0ms
# femur: 92.16, -3.55, 0.0
# tibia: 96.13, 9.67, 0.0
# computed angle: 10.88
# 0.0ms
# femur: 91.55, -2.21, 0.0
# tibia: 96.46, 8.84, 0.0
# computed angle: 10.370000000000001
# 1.7ms
# femur: 91.27, -0.7, 0.0
# tibia: 96.69, 8.26, 0.0
# computed angle: 9.44
# 0.0ms
# femur: 90.83, 0.76, 0.0
# tibia: 96.78, 8.19, 0.0
# computed angle: 8.05
# 0.0ms
# femur: 90.56, 1.97, 0.0
# tibia: 96.86, 7.72, 0.0
# computed angle: 7.31
# 0.0ms
# femur: 90.2, 2.63, 0.0
# tibia: 96.67, 6.89, 0.0
# computed angle: 7.480000000000001
# 0.6ms
# femur: 89.88, 2.44, 0.0
# tibia: 96.81, 5.79, 0.0
# computed angle: 8.77
# 0.0ms
# femur: 89.81, 1.79, 0.0
# tibia: 96.78, 5.21, 0.0
# computed angle: 10.0
# 0.5ms
# femur: 89.76, 0.34, 0.0
# tibia: 96.75, 4.47, 0.0
# computed angle: 12.190000000000001
# 0.0ms
# femur: 89.53, -0.21, 0.0
# tibia: 97.7, 4.55, 0.0
# computed angle: 12.66
# 0.0ms
# femur: 90.16, -0.72, 0.0
# tibia: 98.46, 6.77, 0.0
# computed angle: 10.950000000000001
# 0.0ms
# femur: 90.6, -2.6, 0.0
# tibia: 97.46, 7.6, 0.0
# computed angle: 12.0
# 0.5ms
# femur: 90.88, -4.16, 0.0
# tibia: 96.29, 9.3, 0.0
# computed angle: 11.86
# 6.0ms
# femur: 91.74, -6.1, 0.0
# tibia: 95.92, 11.89, 0.0
# computed angle: 11.21
# 0.0ms
# femur: 92.41, -8.82, 0.0
# tibia: 94.86, 14.48, 0.0
# computed angle: 11.34
# 0.5ms
# femur: 93.39, -11.58, 0.0
# tibia: 94.2, 17.24, 0.0
# computed angle: 11.34
# 0.0ms
# femur: 94.82, -14.38, 0.0
# tibia: 94.15, 20.0, 0.0
# computed angle: 11.380000000000003
# 4.5ms
# femur: 96.2, -17.41, 0.0
# tibia: 93.95, 21.9, 0.0
# computed angle: 12.510000000000002
# 0.0ms
# femur: 97.2, -20.84, 0.0
# tibia: 93.39, 23.61, 0.0
# computed angle: 14.23
# 0.0ms
# femur: 98.5, -24.72, 0.0
# tibia: 93.08, 24.76, 0.0
# computed angle: 16.959999999999997
# 0.0ms
# femur: 100.36, -28.51, 0.0
# tibia: 93.0, 25.79, 0.0
# computed angle: 19.720000000000006
# 0.0ms
# femur: 102.5, -32.25, 0.0
# tibia: 92.82, 26.5, 0.0
# computed angle: 22.75
# 0.0ms
# femur: 103.33, -35.92, 0.0
# tibia: 92.84, 27.25, 0.0
# computed angle: 25.67
# 0.0ms
# femur: 103.91, -39.37, 0.0
# tibia: 93.13, 28.32, 0.0
# computed angle: 28.049999999999997
# 0.0ms
# femur: 104.61, -42.47, 0.0
# tibia: 93.3, 28.9, 0.0
# computed angle: 30.57
# 0.0ms
# femur: 105.87, -45.48, 0.0
# tibia: 93.37, 29.13, 0.0
# computed angle: 33.349999999999994
# 0.0ms
# femur: 107.33, -48.33, 0.0
# tibia: 93.44, 29.28, 0.0
# computed angle: 36.05
# 0.0ms
# femur: 108.69, -50.91, 0.0
# tibia: 93.32, 29.21, 0.0
# computed angle: 38.699999999999996
# 0.0ms
# femur: 109.92, -53.2, 0.0
# tibia: 93.23, 28.99, 0.0
# computed angle: 41.21000000000001
# 0.0ms
# femur: 111.13, -55.24, 0.0
# tibia: 93.35, 28.83, 0.0
# computed angle: 43.41000000000001
# 0.0ms
# femur: 112.28, -57.08, 0.0
# tibia: 93.35, 28.69, 0.0
# computed angle: 45.39
# 0.0ms
# femur: 113.25, -58.86, 0.0
# tibia: 93.29, 28.6, 0.0
# computed angle: 47.26
# 0.0ms
# femur: 114.1, -60.33, 0.0
# tibia: 93.22, 28.35, 0.0
# computed angle: 48.98
# 0.8ms
# femur: 114.91, -61.69, 0.0
# tibia: 93.13, 28.08, 0.0
# computed angle: 50.61
# 0.0ms
# femur: 115.93, -62.97, 0.0
# tibia: 92.64, 27.81, 0.0
# computed angle: 52.16
# 2.7ms
# femur: 116.93, -63.76, 0.0
# tibia: 92.28, 28.13, 0.0
# computed angle: 52.629999999999995
# 0.0ms
# femur: 117.0, -64.33, 0.0
# tibia: 91.84, 28.56, 0.0
# computed angle: 52.769999999999996
# 0.0ms
# femur: 116.86, -64.49, 0.0
# tibia: 91.68, 29.38, 0.0
# computed angle: 52.11
# 0.0ms
# femur: 116.67, -64.4, 0.0
# tibia: 91.14, 30.12, 0.0
# computed angle: 51.28
# 0.0ms
# femur: 115.97, -63.93, 0.0
# tibia: 90.88, 30.82, 0.0
# computed angle: 50.11000000000001
# 0.0ms
# femur: 115.87, -63.16, 0.0
# tibia: 90.31, 31.01, 0.0
# computed angle: 49.14999999999999
# 0.0ms
# femur: 115.34, -61.76, 0.0
# tibia: 89.82, 31.15, 0.0
# computed angle: 47.60999999999999
# 0.0ms
# femur: 114.68, -60.36, 0.0
# tibia: 89.76, 30.8, 0.0
# computed angle: 46.56
# 0.0ms
# femur: 113.12, -58.55, 0.0
# tibia: 88.07, 30.31, 0.0
# computed angle: 45.239999999999995
# 0.0ms
# femur: 112.5, -56.47, 0.0
# tibia: 88.55, 29.77, 0.0
# computed angle: 43.7
# 1.0ms
# femur: 111.02, -54.08, 0.0
# tibia: 87.82, 29.51, 0.0
# computed angle: 41.56999999999999
# 0.0ms
# femur: 109.88, -50.76, 0.0
# tibia: 87.61, 29.51, 0.0
# computed angle: 38.25
# 3.5ms
# femur: 108.24, -48.19, 0.0
# tibia: 88.33, 27.9, 0.0
# computed angle: 37.29
# 0.0ms
# femur: 106.25, -45.13, 0.0
# tibia: 89.75, 26.33, 0.0
# computed angle: 35.800000000000004
# 0.0ms
# femur: 106.31, -41.97, 0.0
# tibia: 90.53, 23.61, 0.0
# computed angle: 35.36
# 1.0ms
# femur: 105.81, -39.74, 0.0
# tibia: 90.94, 21.09, 0.0
# computed angle: 35.650000000000006
# 0.0ms
# femur: 104.17, -36.67, 0.0
# tibia: 91.3, 19.61, 0.0
# computed angle: 34.06
# 0.0ms
# femur: 102.91, -33.2, 0.0
# tibia: 91.82, 18.04, 0.0
# computed angle: 32.160000000000004
# 0.0ms
# femur: 101.92, -29.87, 0.0
# tibia: 92.5, 16.69, 0.0
# computed angle: 30.180000000000003
# 2.8ms
# femur: 100.78, -26.34, 0.0
# tibia: 93.0, 15.71, 0.0
# computed angle: 27.630000000000003
# 0.8ms
# femur: 99.52, -22.99, 0.0
# tibia: 93.57, 14.35, 0.0
# computed angle: 25.639999999999993
# 0.0ms
# femur: 98.79, -19.93, 0.0
# tibia: 94.32, 13.15, 0.0
# computed angle: 23.78
# 0.2ms
# femur: 97.89, -17.21, 0.0
# tibia: 95.09, 11.92, 0.0
# computed angle: 22.29
# 0.0ms
# femur: 97.15, -14.61, 0.0
# tibia: 95.82, 10.76, 0.0
# computed angle: 20.85
# 0.0ms
# femur: 96.47, -11.81, 0.0
# tibia: 96.49, 9.94, 0.0
# computed angle: 18.870000000000005
# 0.0ms
# femur: 95.71, -9.15, 0.0
# tibia: 97.21, 9.07, 0.0
# computed angle: 17.08
# 0.0ms

# %% [markdown]
# at 90: -84:-87 femur and 5:7 for tibia
#
# at 0-> 9:13 femur and 5:7 for tibia
